# %%
#Importing necessary libraries to read data and to do visualizations
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data = pd.read_excel('C:/Users/p_adu/Desktop/Georgia_columns_modified.xlsx')

# %%
data.shape
# Out:
# (37945, 32)

# %%
#data1=data.drop(["HomeValueIQ_z4","zip5","zip4","county","city"], axis=1)
data1=data.drop(["HomeValueIQ_z4"], axis=1)
#GL.drop(["NAICSSTATE","ZIP","Avg_EMP","State","NAICS_Code"], axis=1)

# %%
data1=data1.drop(["zip5","zip4","county","city"], axis=1)

# %%
data.head(5)
# Out:
#     zip5  zip4  county          city Carrier_Route_Type_z4  HomeValueIQ_z4  \
# 0  30002     5  Dekalb  Avondale Est                     B           219.0
# 1  30002   451  Dekalb  Avondale Est                     B             NaN
# 2  30002  1103  Dekalb  Avondale Est                     C           303.0
# 3  30002  1104  Dekalb  Avondale Est                     C           300.0
# 4  30002  1107  Dekalb  Avondale Est                     C           298.0
#
#   DwellingType_z4 Homeowner_Pct_z4 Affordability_Index_z4 Number_of_Autos_z4  \
# 0          Single            Least                 Medium         MediumRisk
# 1          Single            Least                 Medium           HighRisk
# 2          Single             Most                 Medium           HighRisk
# 3          Single             Most                 Medium         MediumRisk
# 4          Single           Medium                 Medium           HighRisk
#
# ...

# %%
data1.isnull().values.any() #Identifying whether data has any missing values
# Out:
# True

# %%
def missing(dff):
    print (round((dff.isnull().sum() * 100/ len(dff)),2).sort_values(ascending=False))

missing(data1)
# Out:
# Age_z4                     1.03
# AIQ_ATP_v2_z4              0.38
# zip5                       0.00
# OS_RiskTaking_Health_z4    0.00
# NumberofAdultsinZip4       0.00
# Education_HS_v2_z4         0.00
# Education_Coll_v2_z4       0.00
# EthnicIQ_v2_z4             0.00
# Gender_Code_z4             0.00
# HW_Telemedicine_SC_z4      0.00
# HW_Stress_v2_z4            0.00
# Spendex_PERS_INS_v2_z4     0.00
# RegB_Ins_Market_AH_z4      0.00
# RegB_Ins_Employer_AH_z4    0.00
# SCR_Wellness_z4            0.00
# HW_ER_Visits_SC_z4         0.00
# IoT_FinTech_Digital_z4     0.00
# zip4                       0.00
# Marriage_Code_z4           0.00
# AIQ_Employment_z4          0.00
# IncomeIQ_Plus_v3_z4        0.00
# Spendex_Plus_v2_z4         0.00
# HW_BMI_z4                  0.00
# Number_of_Autos_z4         0.00
# Affordability_Index_z4     0.00
# Homeowner_Pct_z4           0.00
# DwellingType_z4            0.00
# Carrier_Route_Type_z4      0.00
# city                       0.00
# ...

# %%
#Removing data rows that have missing data elements
data1= data1.dropna()

# %%
missing(data1)
# Out:
# zip5                       0.0
# OS_RiskTaking_Health_z4    0.0
# NumberofAdultsinZip4       0.0
# Education_HS_v2_z4         0.0
# Education_Coll_v2_z4       0.0
# EthnicIQ_v2_z4             0.0
# Gender_Code_z4             0.0
# Age_z4                     0.0
# HW_Telemedicine_SC_z4      0.0
# HW_Stress_v2_z4            0.0
# Spendex_PERS_INS_v2_z4     0.0
# RegB_Ins_Market_AH_z4      0.0
# RegB_Ins_Employer_AH_z4    0.0
# SCR_Wellness_z4            0.0
# HW_ER_Visits_SC_z4         0.0
# IoT_FinTech_Digital_z4     0.0
# zip4                       0.0
# Marriage_Code_z4           0.0
# AIQ_ATP_v2_z4              0.0
# AIQ_Employment_z4          0.0
# IncomeIQ_Plus_v3_z4        0.0
# Spendex_Plus_v2_z4         0.0
# HW_BMI_z4                  0.0
# Number_of_Autos_z4         0.0
# Affordability_Index_z4     0.0
# Homeowner_Pct_z4           0.0
# DwellingType_z4            0.0
# Carrier_Route_Type_z4      0.0
# city                       0.0
# county                     0.0
# ...

# %%
data1.shape
# Out:
# (37425, 31)

# %%
data1.describe()
# Out:
#                zip5          zip4  Spendex_Plus_v2_z4  IncomeIQ_Plus_v3_z4  \
# count  37425.000000  37425.000000        37425.000000         3.742500e+04
# mean   30203.675698   3948.288604        16478.620013         6.075196e+04
# std      148.066338   2240.083622         8364.878897         4.392541e+04
# min    30002.000000      1.000000          888.000000         3.000000e+03
# 25%    30058.000000   2124.000000        11870.000000         3.700000e+04
# 50%    30272.000000   3631.000000        15327.000000         5.200000e+04
# 75%    30318.000000   5566.000000        19701.000000         6.600000e+04
# max    31156.000000   9999.000000       223474.000000         1.080000e+06
#
#        Spendex_PERS_INS_v2_z4        Age_z4  NumberofAdultsinZip4  \
# count            37425.000000  37425.000000          37425.000000
# mean               320.503514     49.780735             11.004088
# std                207.225302     11.141309             11.658497
# ...

# %% [markdown]
# #### Dropping variables that will not be used for analysis

# %%
data2=data1.drop(["Spendex_Plus_v2_z4","zip5","zip4","county","city","NumberHouseholdsInZip4","Spendex_PERS_INS_v2_z4"], axis=1)

# %%
data2=data2.drop(["Gender_Code_z4","EthnicIQ_v2_z4"], axis=1)

# %%
data2 = data2.drop(["Carrier_Route_Type_z4", "DwellingType_z4", "Education_HS_v2_z4", "NumberofAdultsinZip4"], axis=1)

# %%
data2.shape
# Out:
# (37425, 18)

# %%
data2.dtypes
# Out:
# Carrier_Route_Type_z4       object
# DwellingType_z4             object
# Homeowner_Pct_z4            object
# Affordability_Index_z4      object
# Number_of_Autos_z4          object
# HW_BMI_z4                   object
# IncomeIQ_Plus_v3_z4          int64
# AIQ_Employment_z4           object
# AIQ_ATP_v2_z4               object
# Marriage_Code_z4            object
# IoT_FinTech_Digital_z4      object
# OS_RiskTaking_Health_z4     object
# HW_ER_Visits_SC_z4          object
# SCR_Wellness_z4             object
# RegB_Ins_Employer_AH_z4     object
# RegB_Ins_Market_AH_z4       object
# HW_Stress_v2_z4             object
# HW_Telemedicine_SC_z4       object
# Age_z4                     float64
# Gender_Code_z4              object
# EthnicIQ_v2_z4              object
# Education_Coll_v2_z4        object
# Education_HS_v2_z4          object
# NumberofAdultsinZip4         int64
# dtype: object

# %%
data2.shape
# Out:
# (37425, 18)

# %% [markdown]
# ## DATA VISUALIZATION

# %%
# Plotting a Histogram
import matplotlib.pyplot as plt #visualisation
data.city.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title('Number of AA Women by City')
plt.ylabel('Number of women')
plt.xlabel('City')
# Out:
# Text(0.5, 0, 'City')

# %%
# Finding the relations between the variables.
plt.figure(figsize=(20,10))
c= data1.corr()
sns.heatmap(c,cmap='BrBG',annot=True)
c
# Out:
#                             zip5      zip4  Spendex_Plus_v2_z4  \
# zip5                    1.000000 -0.060390            0.085056
# zip4                   -0.060390  1.000000           -0.040714
# Spendex_Plus_v2_z4      0.085056 -0.040714            1.000000
# IncomeIQ_Plus_v3_z4     0.034896 -0.017244            0.697020
# Spendex_PERS_INS_v2_z4  0.085618 -0.040972            0.938795
# Age_z4                  0.012563 -0.085030           -0.198267
# NumberofAdultsinZip4   -0.075798  0.119600           -0.010069
# NumberHouseholdsInZip4 -0.011196  0.100473            0.035321
#
#                         IncomeIQ_Plus_v3_z4  Spendex_PERS_INS_v2_z4    Age_z4  \
# zip5                               0.034896                0.085618  0.012563
# zip4                              -0.017244               -0.040972 -0.085030
# Spendex_Plus_v2_z4                 0.697020                0.938795 -0.198267
# IncomeIQ_Plus_v3_z4                1.000000                0.877564 -0.057843
# ...

# %%
sns.countplot(data['county']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['city']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['Carrier_Route_Type_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['DwellingType_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['Homeowner_Pct_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['Affordability_Index_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['Number_of_Autos_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['HW_BMI_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['AIQ_Employment_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['AIQ_ATP_v2_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['Marriage_Code_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['IoT_FinTech_Digital_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['OS_RiskTaking_Health_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['HW_ER_Visits_SC_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['SCR_Wellness_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['RegB_Ins_Employer_AH_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['RegB_Ins_Market_AH_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['HW_Stress_v2_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.color_palette("Set2")
# Out:
# [(0.4, 0.7607843137254902, 0.6470588235294118),
#  (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
#  (0.5529411764705883, 0.6274509803921569, 0.796078431372549),
#  (0.9058823529411765, 0.5411764705882353, 0.7647058823529411),
#  (0.6509803921568628, 0.8470588235294118, 0.32941176470588235),
#  (1.0, 0.8509803921568627, 0.1843137254901961),
#  (0.8980392156862745, 0.7686274509803922, 0.5803921568627451),
#  (0.7019607843137254, 0.7019607843137254, 0.7019607843137254)]

# %%
sns.countplot(data['Education_Coll_v2_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['Education_Coll_v2_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['Education_HS_v2_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['HW_Telemedicine_SC_z4']);
# Out:
# C:\Users\p_adu\anaconda3\new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data2[numerical].hist(bins=15, figsize=(15, 6), layout=(2, 4));

# %%
g= sns.pairplot(data2)
plt.show()

# %%
data2.dtypes
# Out:
# Carrier_Route_Type_z4       object
# DwellingType_z4             object
# Homeowner_Pct_z4            object
# Affordability_Index_z4      object
# Number_of_Autos_z4          object
# HW_BMI_z4                   object
# IncomeIQ_Plus_v3_z4          int64
# AIQ_Employment_z4           object
# AIQ_ATP_v2_z4               object
# Marriage_Code_z4            object
# IoT_FinTech_Digital_z4      object
# OS_RiskTaking_Health_z4     object
# HW_ER_Visits_SC_z4          object
# SCR_Wellness_z4             object
# RegB_Ins_Employer_AH_z4     object
# RegB_Ins_Market_AH_z4       object
# HW_Stress_v2_z4             object
# HW_Telemedicine_SC_z4       object
# Age_z4                     float64
# Gender_Code_z4              object
# EthnicIQ_v2_z4              object
# Education_Coll_v2_z4        object
# Education_HS_v2_z4          object
# NumberofAdultsinZip4         int64
# dtype: object

# %% [markdown]
# ### DATA PREPARATION BEFORE CLUSTER ANALYSIS

# %%
categorical_cols = ['Homeowner_Pct_z4','Affordability_Index_z4','Number_of_Autos_z4',
                   'HW_BMI_z4','AIQ_Employment_z4','AIQ_ATP_v2_z4','Marriage_Code_z4','IoT_FinTech_Digital_z4','OS_RiskTaking_Health_z4',
                   'HW_ER_Visits_SC_z4','SCR_Wellness_z4','RegB_Ins_Employer_AH_z4','RegB_Ins_Market_AH_z4','HW_Stress_v2_z4',
                   'HW_Telemedicine_SC_z4','Education_Coll_v2_z4']

# %%
data_dummies = pd.get_dummies(data2[categorical_cols], drop_first=True)

# %%
noncategorical_cols = [col for col in data2.columns if col not in categorical_cols]

# %%
data_preprocess = pd.concat([data2[noncategorical_cols], data_dummies], axis=1)

# %%
data_preprocess.shape
# Out:
# (37425, 34)

# %%
print(data_preprocess.isnull().sum())
# Out:
# IncomeIQ_Plus_v3_z4                   0
# Age_z4                                0
# Homeowner_Pct_z4_Medium               0
# Homeowner_Pct_z4_Most                 0
# Affordability_Index_z4_Medium         0
# Affordability_Index_z4_Most           0
# Number_of_Autos_z4_LowRisk            0
# Number_of_Autos_z4_MediumRisk         0
# HW_BMI_z4_LowRisk                     0
# HW_BMI_z4_MediumRisk                  0
# AIQ_Employment_z4_LowRisk             0
# AIQ_Employment_z4_MediumRisk          0
# AIQ_ATP_v2_z4_LowRisk                 0
# AIQ_ATP_v2_z4_MediumRisk              0
# Marriage_Code_z4_Single               0
# Marriage_Code_z4_Unknown              0
# IoT_FinTech_Digital_z4_Medium         0
# IoT_FinTech_Digital_z4_Most           0
# OS_RiskTaking_Health_z4_LowRisk       0
# OS_RiskTaking_Health_z4_MediumRisk    0
# HW_ER_Visits_SC_z4_LowRisk            0
# HW_ER_Visits_SC_z4_MediumRisk         0
# SCR_Wellness_z4_LowRisk               0
# ...

# %% [markdown]
# ### CLUSTER ANALYSIS BASED ON SELECTED RISK FEATURES

# %%
import sklearn.cluster as cluster
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
#scaling numerical features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(data_preprocess)

# %%
sns.set(color_codes=True)
sns.set_style('darkgrid', {'axes.facecolor': '.9'})
sns.set_palette(palette='deep')
sns_c = sns.color_palette(palette='deep')
# %matplotlib inline

# %%
#This run is with scaled features. Identifying optimal clusters using below elbow-plot method
from sklearn.cluster import KMeans

inertias = []

k_candidates = range(1, 10)

for k in k_candidates:
    k_means = KMeans(random_state=42, n_clusters=k)
    k_means.fit(scaled_features)
    inertias.append(k_means.inertia_)

fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(x=k_candidates, y = inertias, s=80, ax=ax)
sns.scatterplot(x=[k_candidates[2]], y = [inertias[2]], color=sns_c[3], s=150, ax=ax)
sns.lineplot(x=k_candidates, y = inertias, alpha=0.5, ax=ax)
ax.set(title='Inertia K-Means', ylabel='inertia', xlabel='k');

# %% [markdown]
# #### Running K-means clustering using 3 clusters obtained from above plot

# %%
from sklearn.cluster import KMeans
k_means = KMeans(random_state=25, n_clusters=3)
k_means.fit(scaled_features)
cluster = k_means.predict(scaled_features)
cluster = ['k-means_c_' + str(c) for c in cluster]

# %%
data_kmeans_data=data1.assign(cluster = cluster)

# %%
#Saving data to excel for further analysis of Risk clusters
data_kmeans_data.to_excel("kmeans_georgia_data2_092521.xlsx")

# %%
# Add the cluster number to the original scaled data
X_clustered = pd.DataFrame(scaled_features, index=data_preprocess.index, columns=data_preprocess.columns)
X_clustered["cluster"] = cluster

# %%
k_means.cluster_centers_
# Out:
# array([[ 0.55021906,  0.97133837, -0.34762719,  0.83682696, -0.17199411,
#          0.15508677,  0.31228035,  0.63734396,  0.1118355 , -0.17649011,
#         -0.55544219, -0.15223935,  0.86568805,  0.27352917, -0.8881672 ,
#          0.10124111, -0.46895583,  0.00534359,  1.4993133 , -0.45030066,
#          1.08630823,  0.00831313,  0.97391569, -0.15455786,  0.51131397,
#          0.16420953, -0.40027893, -0.23292306,  1.89115507, -0.78638552,
#         -0.264011  , -0.48397752, -0.1628356 ,  0.06403451],
#        [-0.21467285,  0.16784209,  0.14849157,  0.02490485,  0.06773628,
#         -0.06659248, -0.05431733, -0.1025971 , -0.51051418,  0.43452034,
#         -0.16541871,  0.17942717, -0.23986606,  0.02492863,  0.13147286,
#         -0.04046287, -0.00199692, -0.28897288, -0.22432608,  0.25055157,
#         -0.23655672, -0.01371661, -0.31123275,  0.08868909, -0.09894248,
#         -0.01185039, -0.09889457,  0.10242836, -0.30018336,  0.41972668,
# ...

# %%
pd.plotting.parallel_coordinates(X_clustered, "cluster", color=["lime", "tomato","dodgerblue"]);
